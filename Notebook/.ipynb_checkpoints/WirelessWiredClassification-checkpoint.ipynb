# %% [markdown]
# # Tesina Intelligent and Secure Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sea

# %%
# Load dataset
data = 'WirelessWiredData.csv'
df = pd.read_csv(data)

# %% [markdown]
# ## Ispezione del dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1202 entries, 0 to 1201
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   latency         1202 non-null   float64
#  1   retransmission  1202 non-null   int64
#  2   bandwidth       1202 non-null   int64
#  3   label           1202 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 37.7+ KB
# None

# %%
# Preview the dataset
print(df.head()) # first 5 elements
# Out:
#     latency  retransmission  bandwidth  label
# 0  0.000019               0   12526266  wired
# 1  0.000026               0   12524238  wired
# 2  0.000017               0   12524730  wired
# 3  0.000017               0   12524730  wired
# 4  0.000020               0   12520524  wired

# %%
# Class distribution
print(df["label"].value_counts())
plt.figure()
figure = (df['label'].value_counts()*100.0 /len(df))\
		.plot.pie(autopct='%.1f%%', labels = ['wired', 'wireless'])
plt.show()
# Out:
# wired       601
# wireless    601
# Name: label, dtype: int64

# %% [markdown]
# Il dataset è ovviamente bilanciato!

# %%
# Class numerical conversion
df["label"]=[0 if i == "wired" else 1 for i in df["label"]]

# %%
# View summary statistics in numerical variables
print(round(df.describe(),2))
# Out:
#        latency  retransmission    bandwidth   label
# count  1202.00         1202.00      1202.00  1202.0
# mean      0.00           66.78   6932225.38     0.5
# std       0.00          113.11   5046342.01     0.5
# min       0.00            0.00         0.00     0.0
# 25%       0.00            0.00   2201455.50     0.0
# 50%       0.00            0.00   2857770.00     0.5
# 75%       0.00          116.50  12524722.00     1.0
# max       0.09         1645.00  13002582.00     1.0

# %%
features = list(df.columns)
features.remove('label')
class_ = ['wired', 'wireless']
j=1
plt.figure(figsize=(20,30))
for f in features:
    plt.subplot(3, 1, j)
    for i in range(2):
        sea.kdeplot(data=df[df["label"] == i][f], label = class_[i], fill = True)
        plt.legend()
    j += 1

# %% [markdown]
# ## Analisi delle features

# %%
print(features)

plt.figure(figsize=(20,40))

i=1
for f in features:
    plt.subplot(10, 2, i)
    fig = df.boxplot(column=f)
    fig.set_title('')
    fig.set_ylabel(f)
    i += 1
# Out:
# ['latency', 'retransmission', 'bandwidth']

# %% [markdown]
# ### Rimozione outlier

# %%
# Specify the columns containing the data with outliers
column_names = ['latency', 'retransmission']

# Calculate the interquartile range (IQR) for each column
Q1 = df[column_names].quantile(0.25)
Q3 = df[column_names].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds to identify outliers for each column
lower_bound = Q1 - 10 * IQR
upper_bound = Q3 + 10 * IQR

# Filter out rows that have values outside the bounds for either column
filtered_data = df[
    (df[column_names[0]] >= lower_bound[column_names[0]]) &
    (df[column_names[0]] <= upper_bound[column_names[0]]) &
    (df[column_names[1]] >= lower_bound[column_names[1]]) &
    (df[column_names[1]] <= upper_bound[column_names[1]])
]

df = filtered_data

# boxplot
features = list(df.columns)
features.remove('label')
print(features)

plt.figure(figsize=(20,40))

i=1
for f in features:
    plt.subplot(10, 2, i)
    fig = df.boxplot(column=f)
    fig.set_title('')
    fig.set_ylabel(f)
    i += 1

# Class distribution
print(df["label"].value_counts())
plt.figure()
figure = (df['label'].value_counts()*100.0 /len(df))\
		.plot.pie(autopct='%.1f%%', labels = ['wired', 'wireless'])
plt.show()
# Out:
# ['latency', 'retransmission', 'bandwidth']
# 1    601
# 0    598
# Name: label, dtype: int64

# %% [markdown]
# ### Correlazione

# %%
features_data = df[features]
plt.figure(figsize = (9,7))
sea.heatmap(features_data.corr(), annot = True)
plt.show()

# %%
plt.figure(figsize=(2,8))
corr_matrix = df.corr()
sea.heatmap(corr_matrix[['label']], annot=True)
plt.show()

# %% [markdown]
# ## Data splitting & Normalization

# %%
# Shuffle the dataset
df = df.sample(frac=1)
# Preview the dataset
print(df.head()) # first 5 elements
# Out:
#        latency  retransmission  bandwidth  label
# 695   0.003885             380    1699516      1
# 26    0.000016               0   12521064      0
# 1001  0.004724             303    2315628      1
# 630   0.009848             209    2014482      1
# 948   0.000437              25    2088048      1

# %%
# Split data
X = df.drop(['label'], axis=1)
t = df['label']

# %%
# Split X and t into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, t_train, t_test = train_test_split(X, t, test_size = 0.3, random_state = 0)

# %%
# Check the shape of X_train and X_test
print(X_train.shape)
print(X_test.shape)
# Out:
# (839, 3)
# (360, 3)

# %%
# Normalization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Export the scaler
from joblib import dump
dump(scaler, 'scaler.pkl')

# Check if data is normalized
print(X_train.mean(axis=0))
print(X_train.std(axis=0))
# Out:
# [-5.29307759e-17 -1.69378483e-17 -1.27033862e-17]
# [1. 1. 1.]

# %% [markdown]
# ## Training

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, make_scorer

# %%
# Initialize the softmax regression model
logistic_reg = LogisticRegression(solver='lbfgs', C=1, max_iter=1000)
grid = {"C": np.logspace(-5, 10, 30)}

# %%
# Perform grid search cross-validation with f1 as the scoring metric
f1 = make_scorer(f1_score)
logistic_reg_cv = GridSearchCV(logistic_reg, grid, cv=5, scoring=f1)
logistic_reg_cv.fit(X_train, t_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(C=1, max_iter=1000),
#              param_grid={'C': array([1.00000000e-05, 3.29034456e-05, 1.08263673e-04, 3.56224789e-04,
#        1.17210230e-03, 3.85662042e-03, 1.26896100e-02, 4.17531894e-02,
#        1.37382380e-01, 4.52035366e-01, 1.48735211e+00, 4.89390092e+00,
#        1.61026203e+01, 5.29831691e+01, 1.74332882e+02, 5.73615251e+02,
#        1.88739182e+03, 6.21016942e+03, 2.04335972e+04, 6.72335754e+04,
#        2.21221629e+05, 7.27895384e+05, 2.39502662e+06, 7.88046282e+06,
#        2.59294380e+07, 8.53167852e+07, 2.80721620e+08, 9.23670857e+08,
#        3.03919538e+09, 1.00000000e+10])},
#              scoring=make_scorer(f1_score))

# %%
# Print the best parameters and accuracy from the grid search
print("Tuned hyperparameters (best parameters): ", logistic_reg_cv.best_params_)
print("F1: ", logistic_reg_cv.best_score_)
# Out:
# Tuned hyperparameters (best parameters):  {'C': 0.0003562247890262444}
# F1:  0.9835704471760675

# %%
Y_hat_test = logistic_reg_cv.predict(X_test)
print("Accuracy score on the test set: ", accuracy_score(t_test, Y_hat_test))
print("F1 score on the test set: ", f1_score(t_test, Y_hat_test))
# Out:
# Accuracy score on the test set:  0.9777777777777777
# F1 score on the test set:  0.9783783783783783

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(t_test, Y_hat_test, labels=[0,1])
cm_matrix = pd.DataFrame(data=cm, columns=['wired', 'wireless'],
                                  index=['wired', 'wireless'])

sea.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %% [markdown]
# ### SVM

# %%
# import SVC classifier
from sklearn.svm import SVC

# %%
# import metrics to compute accuracy
from sklearn.metrics import accuracy_score, f1_score, classification_report

# %%
# instantiate classifier with default hyperparameters
svc=SVC()

# %%
# import GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
# declare parameters for hyperparameter tuning
parameters = [ {'C':[1, 10, 100, 1000], 'kernel':['linear']},
               {'C':[1, 10, 100, 1000], 'kernel':['rbf'], 'gamma':[0.1, 0.2, 0.3, 0.4]},
               {'C':[1, 10, 100, 1000], 'kernel':['poly'], 'degree': [2] ,'gamma':[0.01,0.02]}
              ]

grid_search = GridSearchCV(estimator = svc,
                           param_grid = parameters,
                           scoring = 'f1_weighted',
                           cv = 5,
                           verbose=10)

# %%
grid_search.fit(X_train, t_train)
# Out:
# Fitting 5 folds for each of 28 candidates, totalling 140 fits
# [CV 1/5; 1/28] START C=1, kernel=linear.........................................
# [CV 1/5; 1/28] END ..........C=1, kernel=linear;, score=0.958 total time=   0.0s
# [CV 2/5; 1/28] START C=1, kernel=linear.........................................
# [CV 2/5; 1/28] END ..........C=1, kernel=linear;, score=0.982 total time=   0.0s
# [CV 3/5; 1/28] START C=1, kernel=linear.........................................
# [CV 3/5; 1/28] END ..........C=1, kernel=linear;, score=0.982 total time=   0.0s
# [CV 4/5; 1/28] START C=1, kernel=linear.........................................
# [CV 4/5; 1/28] END ..........C=1, kernel=linear;, score=0.976 total time=   0.0s
# [CV 5/5; 1/28] START C=1, kernel=linear.........................................
# [CV 5/5; 1/28] END ..........C=1, kernel=linear;, score=0.976 total time=   0.0s
# [CV 1/5; 2/28] START C=10, kernel=linear........................................
# [CV 1/5; 2/28] END .........C=10, kernel=linear;, score=0.976 total time=   0.0s
# [CV 2/5; 2/28] START C=10, kernel=linear........................................
# [CV 2/5; 2/28] END .........C=10, kernel=linear;, score=0.982 total time=   0.0s
# [CV 3/5; 2/28] START C=10, kernel=linear........................................
# [CV 3/5; 2/28] END .........C=10, kernel=linear;, score=0.982 total time=   0.0s
# [CV 4/5; 2/28] START C=10, kernel=linear........................................
# [CV 4/5; 2/28] END .........C=10, kernel=linear;, score=0.976 total time=   0.0s
# [CV 5/5; 2/28] START C=10, kernel=linear........................................
# [CV 5/5; 2/28] END .........C=10, kernel=linear;, score=0.976 total time=   0.0s
# [CV 1/5; 3/28] START C=100, kernel=linear.......................................
# [CV 1/5; 3/28] END ........C=100, kernel=linear;, score=0.976 total time=   0.0s
# [CV 2/5; 3/28] START C=100, kernel=linear.......................................
# [CV 2/5; 3/28] END ........C=100, kernel=linear;, score=0.982 total time=   0.0s
# [CV 3/5; 3/28] START C=100, kernel=linear.......................................
# [CV 3/5; 3/28] END ........C=100, kernel=linear;, score=0.982 total time=   0.0s
# [CV 4/5; 3/28] START C=100, kernel=linear.......................................
# [CV 4/5; 3/28] END ........C=100, kernel=linear;, score=0.976 total time=   0.0s
# [CV 5/5; 3/28] START C=100, kernel=linear.......................................
# [CV 5/5; 3/28] END ........C=100, kernel=linear;, score=0.982 total time=   0.0s
# [CV 1/5; 4/28] START C=1000, kernel=linear......................................
# [CV 1/5; 4/28] END .......C=1000, kernel=linear;, score=0.976 total time=   0.0s
# [CV 2/5; 4/28] START C=1000, kernel=linear......................................
# [CV 2/5; 4/28] END .......C=1000, kernel=linear;, score=0.982 total time=   0.0s
# [CV 3/5; 4/28] START C=1000, kernel=linear......................................
# [CV 3/5; 4/28] END .......C=1000, kernel=linear;, score=0.982 total time=   0.0s
# [CV 4/5; 4/28] START C=1000, kernel=linear......................................
# [CV 4/5; 4/28] END .......C=1000, kernel=linear;, score=0.976 total time=   0.0s
# [CV 5/5; 4/28] START C=1000, kernel=linear......................................
# [CV 5/5; 4/28] END .......C=1000, kernel=linear;, score=0.982 total time=   0.0s
# [CV 1/5; 5/28] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 1/5; 5/28] END ..C=1, gamma=0.1, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 2/5; 5/28] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 2/5; 5/28] END ..C=1, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 3/5; 5/28] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 3/5; 5/28] END ..C=1, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 5/28] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 4/5; 5/28] END ..C=1, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 5/28] START C=1, gamma=0.1, kernel=rbf.................................
# [CV 5/5; 5/28] END ..C=1, gamma=0.1, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 1/5; 6/28] START C=1, gamma=0.2, kernel=rbf.................................
# [CV 1/5; 6/28] END ..C=1, gamma=0.2, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 2/5; 6/28] START C=1, gamma=0.2, kernel=rbf.................................
# [CV 2/5; 6/28] END ..C=1, gamma=0.2, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 3/5; 6/28] START C=1, gamma=0.2, kernel=rbf.................................
# [CV 3/5; 6/28] END ..C=1, gamma=0.2, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 6/28] START C=1, gamma=0.2, kernel=rbf.................................
# [CV 4/5; 6/28] END ..C=1, gamma=0.2, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 6/28] START C=1, gamma=0.2, kernel=rbf.................................
# [CV 5/5; 6/28] END ..C=1, gamma=0.2, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 1/5; 7/28] START C=1, gamma=0.3, kernel=rbf.................................
# [CV 1/5; 7/28] END ..C=1, gamma=0.3, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 2/5; 7/28] START C=1, gamma=0.3, kernel=rbf.................................
# [CV 2/5; 7/28] END ..C=1, gamma=0.3, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 3/5; 7/28] START C=1, gamma=0.3, kernel=rbf.................................
# [CV 3/5; 7/28] END ..C=1, gamma=0.3, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 7/28] START C=1, gamma=0.3, kernel=rbf.................................
# [CV 4/5; 7/28] END ..C=1, gamma=0.3, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 7/28] START C=1, gamma=0.3, kernel=rbf.................................
# [CV 5/5; 7/28] END ..C=1, gamma=0.3, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5; 8/28] START C=1, gamma=0.4, kernel=rbf.................................
# [CV 1/5; 8/28] END ..C=1, gamma=0.4, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 2/5; 8/28] START C=1, gamma=0.4, kernel=rbf.................................
# [CV 2/5; 8/28] END ..C=1, gamma=0.4, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 3/5; 8/28] START C=1, gamma=0.4, kernel=rbf.................................
# [CV 3/5; 8/28] END ..C=1, gamma=0.4, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 8/28] START C=1, gamma=0.4, kernel=rbf.................................
# [CV 4/5; 8/28] END ..C=1, gamma=0.4, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 8/28] START C=1, gamma=0.4, kernel=rbf.................................
# [CV 5/5; 8/28] END ..C=1, gamma=0.4, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5; 9/28] START C=10, gamma=0.1, kernel=rbf................................
# [CV 1/5; 9/28] END .C=10, gamma=0.1, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 2/5; 9/28] START C=10, gamma=0.1, kernel=rbf................................
# [CV 2/5; 9/28] END .C=10, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 3/5; 9/28] START C=10, gamma=0.1, kernel=rbf................................
# [CV 3/5; 9/28] END .C=10, gamma=0.1, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 9/28] START C=10, gamma=0.1, kernel=rbf................................
# [CV 4/5; 9/28] END .C=10, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 9/28] START C=10, gamma=0.1, kernel=rbf................................
# [CV 5/5; 9/28] END .C=10, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5; 10/28] START C=10, gamma=0.2, kernel=rbf...............................
# [CV 1/5; 10/28] END C=10, gamma=0.2, kernel=rbf;, score=0.964 total time=   0.0s
# [CV 2/5; 10/28] START C=10, gamma=0.2, kernel=rbf...............................
# [CV 2/5; 10/28] END C=10, gamma=0.2, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 3/5; 10/28] START C=10, gamma=0.2, kernel=rbf...............................
# [CV 3/5; 10/28] END C=10, gamma=0.2, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 10/28] START C=10, gamma=0.2, kernel=rbf...............................
# [CV 4/5; 10/28] END C=10, gamma=0.2, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 10/28] START C=10, gamma=0.2, kernel=rbf...............................
# [CV 5/5; 10/28] END C=10, gamma=0.2, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5; 11/28] START C=10, gamma=0.3, kernel=rbf...............................
# [CV 1/5; 11/28] END C=10, gamma=0.3, kernel=rbf;, score=0.952 total time=   0.0s
# [CV 2/5; 11/28] START C=10, gamma=0.3, kernel=rbf...............................
# [CV 2/5; 11/28] END C=10, gamma=0.3, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5; 11/28] START C=10, gamma=0.3, kernel=rbf...............................
# [CV 3/5; 11/28] END C=10, gamma=0.3, kernel=rbf;, score=0.982 total time=   0.0s
# [CV 4/5; 11/28] START C=10, gamma=0.3, kernel=rbf...............................
# [CV 4/5; 11/28] END C=10, gamma=0.3, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 11/28] START C=10, gamma=0.3, kernel=rbf...............................
# [CV 5/5; 11/28] END C=10, gamma=0.3, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 1/5; 12/28] START C=10, gamma=0.4, kernel=rbf...............................
# [CV 1/5; 12/28] END C=10, gamma=0.4, kernel=rbf;, score=0.958 total time=   0.0s
# [CV 2/5; 12/28] START C=10, gamma=0.4, kernel=rbf...............................
# [CV 2/5; 12/28] END C=10, gamma=0.4, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5; 12/28] START C=10, gamma=0.4, kernel=rbf...............................
# [CV 3/5; 12/28] END C=10, gamma=0.4, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 12/28] START C=10, gamma=0.4, kernel=rbf...............................
# [CV 4/5; 12/28] END C=10, gamma=0.4, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 5/5; 12/28] START C=10, gamma=0.4, kernel=rbf...............................
# [CV 5/5; 12/28] END C=10, gamma=0.4, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 1/5; 13/28] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 1/5; 13/28] END C=100, gamma=0.1, kernel=rbf;, score=0.946 total time=   0.0s
# [CV 2/5; 13/28] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 2/5; 13/28] END C=100, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5; 13/28] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 3/5; 13/28] END C=100, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 13/28] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 4/5; 13/28] END C=100, gamma=0.1, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 5/5; 13/28] START C=100, gamma=0.1, kernel=rbf..............................
# [CV 5/5; 13/28] END C=100, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 1/5; 14/28] START C=100, gamma=0.2, kernel=rbf..............................
# [CV 1/5; 14/28] END C=100, gamma=0.2, kernel=rbf;, score=0.964 total time=   0.0s
# [CV 2/5; 14/28] START C=100, gamma=0.2, kernel=rbf..............................
# [CV 2/5; 14/28] END C=100, gamma=0.2, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 3/5; 14/28] START C=100, gamma=0.2, kernel=rbf..............................
# [CV 3/5; 14/28] END C=100, gamma=0.2, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 14/28] START C=100, gamma=0.2, kernel=rbf..............................
# [CV 4/5; 14/28] END C=100, gamma=0.2, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 5/5; 14/28] START C=100, gamma=0.2, kernel=rbf..............................
# [CV 5/5; 14/28] END C=100, gamma=0.2, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 1/5; 15/28] START C=100, gamma=0.3, kernel=rbf..............................
# [CV 1/5; 15/28] END C=100, gamma=0.3, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 2/5; 15/28] START C=100, gamma=0.3, kernel=rbf..............................
# [CV 2/5; 15/28] END C=100, gamma=0.3, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 3/5; 15/28] START C=100, gamma=0.3, kernel=rbf..............................
# [CV 3/5; 15/28] END C=100, gamma=0.3, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 15/28] START C=100, gamma=0.3, kernel=rbf..............................
# [CV 4/5; 15/28] END C=100, gamma=0.3, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5; 15/28] START C=100, gamma=0.3, kernel=rbf..............................
# [CV 5/5; 15/28] END C=100, gamma=0.3, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 1/5; 16/28] START C=100, gamma=0.4, kernel=rbf..............................
# [CV 1/5; 16/28] END C=100, gamma=0.4, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 2/5; 16/28] START C=100, gamma=0.4, kernel=rbf..............................
# [CV 2/5; 16/28] END C=100, gamma=0.4, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 3/5; 16/28] START C=100, gamma=0.4, kernel=rbf..............................
# [CV 3/5; 16/28] END C=100, gamma=0.4, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 16/28] START C=100, gamma=0.4, kernel=rbf..............................
# [CV 4/5; 16/28] END C=100, gamma=0.4, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5; 16/28] START C=100, gamma=0.4, kernel=rbf..............................
# [CV 5/5; 16/28] END C=100, gamma=0.4, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 1/5; 17/28] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 1/5; 17/28] END C=1000, gamma=0.1, kernel=rbf;, score=0.970 total time=   0.0s
# [CV 2/5; 17/28] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 2/5; 17/28] END C=1000, gamma=0.1, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 3/5; 17/28] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 3/5; 17/28] END C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 17/28] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 4/5; 17/28] END C=1000, gamma=0.1, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5; 17/28] START C=1000, gamma=0.1, kernel=rbf.............................
# [CV 5/5; 17/28] END C=1000, gamma=0.1, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 1/5; 18/28] START C=1000, gamma=0.2, kernel=rbf.............................
# [CV 1/5; 18/28] END C=1000, gamma=0.2, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 2/5; 18/28] START C=1000, gamma=0.2, kernel=rbf.............................
# [CV 2/5; 18/28] END C=1000, gamma=0.2, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 3/5; 18/28] START C=1000, gamma=0.2, kernel=rbf.............................
# [CV 3/5; 18/28] END C=1000, gamma=0.2, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 18/28] START C=1000, gamma=0.2, kernel=rbf.............................
# [CV 4/5; 18/28] END C=1000, gamma=0.2, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5; 18/28] START C=1000, gamma=0.2, kernel=rbf.............................
# [CV 5/5; 18/28] END C=1000, gamma=0.2, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 1/5; 19/28] START C=1000, gamma=0.3, kernel=rbf.............................
# [CV 1/5; 19/28] END C=1000, gamma=0.3, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 2/5; 19/28] START C=1000, gamma=0.3, kernel=rbf.............................
# [CV 2/5; 19/28] END C=1000, gamma=0.3, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 3/5; 19/28] START C=1000, gamma=0.3, kernel=rbf.............................
# [CV 3/5; 19/28] END C=1000, gamma=0.3, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 19/28] START C=1000, gamma=0.3, kernel=rbf.............................
# [CV 4/5; 19/28] END C=1000, gamma=0.3, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5; 19/28] START C=1000, gamma=0.3, kernel=rbf.............................
# [CV 5/5; 19/28] END C=1000, gamma=0.3, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 1/5; 20/28] START C=1000, gamma=0.4, kernel=rbf.............................
# [CV 1/5; 20/28] END C=1000, gamma=0.4, kernel=rbf;, score=0.976 total time=   0.0s
# [CV 2/5; 20/28] START C=1000, gamma=0.4, kernel=rbf.............................
# [CV 2/5; 20/28] END C=1000, gamma=0.4, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 3/5; 20/28] START C=1000, gamma=0.4, kernel=rbf.............................
# [CV 3/5; 20/28] END C=1000, gamma=0.4, kernel=rbf;, score=0.988 total time=   0.0s
# [CV 4/5; 20/28] START C=1000, gamma=0.4, kernel=rbf.............................
# [CV 4/5; 20/28] END C=1000, gamma=0.4, kernel=rbf;, score=1.000 total time=   0.0s
# [CV 5/5; 20/28] START C=1000, gamma=0.4, kernel=rbf.............................
# [CV 5/5; 20/28] END C=1000, gamma=0.4, kernel=rbf;, score=0.994 total time=   0.0s
# [CV 1/5; 21/28] START C=1, degree=2, gamma=0.01, kernel=poly....................
# [CV 1/5; 21/28] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.384 total time=   0.0s
# [CV 2/5; 21/28] START C=1, degree=2, gamma=0.01, kernel=poly....................
# [CV 2/5; 21/28] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.396 total time=   0.0s
# [CV 3/5; 21/28] START C=1, degree=2, gamma=0.01, kernel=poly....................
# [CV 3/5; 21/28] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.372 total time=   0.0s
# [CV 4/5; 21/28] START C=1, degree=2, gamma=0.01, kernel=poly....................
# [CV 4/5; 21/28] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.372 total time=   0.0s
# [CV 5/5; 21/28] START C=1, degree=2, gamma=0.01, kernel=poly....................
# [CV 5/5; 21/28] END C=1, degree=2, gamma=0.01, kernel=poly;, score=0.350 total time=   0.0s
# [CV 1/5; 22/28] START C=1, degree=2, gamma=0.02, kernel=poly....................
# [CV 1/5; 22/28] END C=1, degree=2, gamma=0.02, kernel=poly;, score=0.408 total time=   0.0s
# [CV 2/5; 22/28] START C=1, degree=2, gamma=0.02, kernel=poly....................
# [CV 2/5; 22/28] END C=1, degree=2, gamma=0.02, kernel=poly;, score=0.420 total time=   0.0s
# [CV 3/5; 22/28] START C=1, degree=2, gamma=0.02, kernel=poly....................
# [CV 3/5; 22/28] END C=1, degree=2, gamma=0.02, kernel=poly;, score=0.408 total time=   0.0s
# [CV 4/5; 22/28] START C=1, degree=2, gamma=0.02, kernel=poly....................
# [CV 4/5; 22/28] END C=1, degree=2, gamma=0.02, kernel=poly;, score=0.453 total time=   0.0s
# [CV 5/5; 22/28] START C=1, degree=2, gamma=0.02, kernel=poly....................
# [CV 5/5; 22/28] END C=1, degree=2, gamma=0.02, kernel=poly;, score=0.458 total time=   0.0s
# [CV 1/5; 23/28] START C=10, degree=2, gamma=0.01, kernel=poly...................
# [CV 1/5; 23/28] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.450 total time=   0.0s
# [CV 2/5; 23/28] START C=10, degree=2, gamma=0.01, kernel=poly...................
# [CV 2/5; 23/28] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.464 total time=   0.0s
# [CV 3/5; 23/28] START C=10, degree=2, gamma=0.01, kernel=poly...................
# [CV 3/5; 23/28] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.475 total time=   0.0s
# [CV 4/5; 23/28] START C=10, degree=2, gamma=0.01, kernel=poly...................
# [CV 4/5; 23/28] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.485 total time=   0.0s
# [CV 5/5; 23/28] START C=10, degree=2, gamma=0.01, kernel=poly...................
# [CV 5/5; 23/28] END C=10, degree=2, gamma=0.01, kernel=poly;, score=0.500 total time=   0.0s
# [CV 1/5; 24/28] START C=10, degree=2, gamma=0.02, kernel=poly...................
# [CV 1/5; 24/28] END C=10, degree=2, gamma=0.02, kernel=poly;, score=0.632 total time=   0.0s
# [CV 2/5; 24/28] START C=10, degree=2, gamma=0.02, kernel=poly...................
# [CV 2/5; 24/28] END C=10, degree=2, gamma=0.02, kernel=poly;, score=0.608 total time=   0.0s
# [CV 3/5; 24/28] START C=10, degree=2, gamma=0.02, kernel=poly...................
# [CV 3/5; 24/28] END C=10, degree=2, gamma=0.02, kernel=poly;, score=0.662 total time=   0.0s
# [CV 4/5; 24/28] START C=10, degree=2, gamma=0.02, kernel=poly...................
# [CV 4/5; 24/28] END C=10, degree=2, gamma=0.02, kernel=poly;, score=0.647 total time=   0.0s
# [CV 5/5; 24/28] START C=10, degree=2, gamma=0.02, kernel=poly...................
# [CV 5/5; 24/28] END C=10, degree=2, gamma=0.02, kernel=poly;, score=0.711 total time=   0.0s
# [CV 1/5; 25/28] START C=100, degree=2, gamma=0.01, kernel=poly..................
# [CV 1/5; 25/28] END C=100, degree=2, gamma=0.01, kernel=poly;, score=0.735 total time=   0.0s
# [CV 2/5; 25/28] START C=100, degree=2, gamma=0.01, kernel=poly..................
# [CV 2/5; 25/28] END C=100, degree=2, gamma=0.01, kernel=poly;, score=0.699 total time=   0.0s
# [CV 3/5; 25/28] START C=100, degree=2, gamma=0.01, kernel=poly..................
# [CV 3/5; 25/28] END C=100, degree=2, gamma=0.01, kernel=poly;, score=0.768 total time=   0.0s
# [CV 4/5; 25/28] START C=100, degree=2, gamma=0.01, kernel=poly..................
# [CV 4/5; 25/28] END C=100, degree=2, gamma=0.01, kernel=poly;, score=0.794 total time=   0.0s
# [CV 5/5; 25/28] START C=100, degree=2, gamma=0.01, kernel=poly..................
# [CV 5/5; 25/28] END C=100, degree=2, gamma=0.01, kernel=poly;, score=0.787 total time=   0.0s
# [CV 1/5; 26/28] START C=100, degree=2, gamma=0.02, kernel=poly..................
# [CV 1/5; 26/28] END C=100, degree=2, gamma=0.02, kernel=poly;, score=0.798 total time=   0.0s
# [CV 2/5; 26/28] START C=100, degree=2, gamma=0.02, kernel=poly..................
# [CV 2/5; 26/28] END C=100, degree=2, gamma=0.02, kernel=poly;, score=0.776 total time=   0.0s
# [CV 3/5; 26/28] START C=100, degree=2, gamma=0.02, kernel=poly..................
# [CV 3/5; 26/28] END C=100, degree=2, gamma=0.02, kernel=poly;, score=0.827 total time=   0.0s
# [CV 4/5; 26/28] START C=100, degree=2, gamma=0.02, kernel=poly..................
# [CV 4/5; 26/28] END C=100, degree=2, gamma=0.02, kernel=poly;, score=0.857 total time=   0.0s
# [CV 5/5; 26/28] START C=100, degree=2, gamma=0.02, kernel=poly..................
# [CV 5/5; 26/28] END C=100, degree=2, gamma=0.02, kernel=poly;, score=0.802 total time=   0.0s
# [CV 1/5; 27/28] START C=1000, degree=2, gamma=0.01, kernel=poly.................
# [CV 1/5; 27/28] END C=1000, degree=2, gamma=0.01, kernel=poly;, score=0.833 total time=   0.0s
# [CV 2/5; 27/28] START C=1000, degree=2, gamma=0.01, kernel=poly.................
# [CV 2/5; 27/28] END C=1000, degree=2, gamma=0.01, kernel=poly;, score=0.807 total time=   0.0s
# [CV 3/5; 27/28] START C=1000, degree=2, gamma=0.01, kernel=poly.................
# [CV 3/5; 27/28] END C=1000, degree=2, gamma=0.01, kernel=poly;, score=0.857 total time=   0.0s
# [CV 4/5; 27/28] START C=1000, degree=2, gamma=0.01, kernel=poly.................
# [CV 4/5; 27/28] END C=1000, degree=2, gamma=0.01, kernel=poly;, score=0.875 total time=   0.0s
# [CV 5/5; 27/28] START C=1000, degree=2, gamma=0.01, kernel=poly.................
# [CV 5/5; 27/28] END C=1000, degree=2, gamma=0.01, kernel=poly;, score=0.844 total time=   0.0s
# [CV 1/5; 28/28] START C=1000, degree=2, gamma=0.02, kernel=poly.................
# [CV 1/5; 28/28] END C=1000, degree=2, gamma=0.02, kernel=poly;, score=0.851 total time=   0.0s
# [CV 2/5; 28/28] START C=1000, degree=2, gamma=0.02, kernel=poly.................
# [CV 2/5; 28/28] END C=1000, degree=2, gamma=0.02, kernel=poly;, score=0.814 total time=   0.0s
# [CV 3/5; 28/28] START C=1000, degree=2, gamma=0.02, kernel=poly.................
# [CV 3/5; 28/28] END C=1000, degree=2, gamma=0.02, kernel=poly;, score=0.875 total time=   0.0s
# [CV 4/5; 28/28] START C=1000, degree=2, gamma=0.02, kernel=poly.................
# [CV 4/5; 28/28] END C=1000, degree=2, gamma=0.02, kernel=poly;, score=0.899 total time=   0.0s
# [CV 5/5; 28/28] START C=1000, degree=2, gamma=0.02, kernel=poly.................
# [CV 5/5; 28/28] END C=1000, degree=2, gamma=0.02, kernel=poly;, score=0.880 total time=   0.0s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000],
#                           'gamma': [0.1, 0.2, 0.3, 0.4], 'kernel': ['rbf']},
#                          {'C': [1, 10, 100, 1000], 'degree': [2],
#                           'gamma': [0.01, 0.02], 'kernel': ['poly']}],
#              scoring='f1_weighted', verbose=10)

# %%
# examine the best model

# best score achieved during the GridSearchCV
print('GridSearch CV best score : {:.4f}\n\n'.format(grid_search.best_score_))

# print parameters that give the best results
print('Parameters that give the best results :','\n\n', (grid_search.best_params_))

# print estimator that was chosen by the GridSearch
print('\n\nEstimator that was chosen by the search :','\n\n', (grid_search.best_estimator_))

estimator = grid_search.best_estimator_

from joblib import dump
dump(estimator, "bestModelSVM.joblib")

# calculate GridSearch CV score on test set
t_pred = estimator.predict(X_test)

print('Model classification report with GridSearch CV: \n', classification_report(t_test, t_pred))
# Out:
# GridSearch CV best score : 0.9905
#
#
# Parameters that give the best results :
#
#  {'C': 1000, 'gamma': 0.3, 'kernel': 'rbf'}
#
#
# Estimator that was chosen by the search :
#
#  SVC(C=1000, gamma=0.3)
# Model classification report with GridSearch CV:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       178
#            1       0.99      0.99      0.99       182
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %%
cm = confusion_matrix(t_test, t_pred, labels=[0,1])
cm_matrix = pd.DataFrame(data=cm, columns=['wired', 'wireless'],
                                  index=['wired', 'wireless'])

sea.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()

# %% [markdown]
# ## Impatto delle singole features

# %% [markdown]
# ### Latenza

# %%
svc=SVC()
parameters = [ {'C':[1, 10, 100, 1000], 'kernel':['linear']},
               {'C':[1, 10, 100, 1000], 'kernel':['rbf'], 'gamma':[0.1, 0.2, 0.3, 0.4]},
               {'C':[1, 10, 100, 1000], 'kernel':['poly'], 'degree': [2] ,'gamma':[0.01,0.02]}
              ]

grid_search = GridSearchCV(estimator = svc,
                           param_grid = parameters,
                           scoring = 'f1_weighted',
                           cv = 5,
                           verbose=10)

X_train_latency = np.delete(X_train, [1,2], axis=1)

grid_search.fit(np.delete(X_train, columns_to_remove, axis=1), t_train)
# examine the best model

# best score achieved during the GridSearchCV
print('GridSearch CV best score : {:.4f}\n\n'.format(grid_search.best_score_))

# print parameters that give the best results
print('Parameters that give the best results :','\n\n', (grid_search.best_params_))

# print estimator that was chosen by the GridSearch
print('\n\nEstimator that was chosen by the search :','\n\n', (grid_search.best_estimator_))

estimator = grid_search.best_estimator_

from joblib import dump
dump(estimator, "bestModelSVM.joblib")

# calculate GridSearch CV score on test set
t_pred = estimator.predict(X_test)

print('Model classification report with GridSearch CV: \n', classification_report(t_test, t_pred))
cm = confusion_matrix(t_test, t_pred, labels=[0,1])
cm_matrix = pd.DataFrame(data=cm, columns=['wired', 'wireless'],
                                  index=['wired', 'wireless'])

sea.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 12
#       2 parameters = [ {'C':[1, 10, 100, 1000], 'kernel':['linear']},
#       3                {'C':[1, 10, 100, 1000], 'kernel':['rbf'], 'gamma':[0.1, 0.2, 0.3, 0.4]},
#       4                {'C':[1, 10, 100, 1000], 'kernel':['poly'], 'degree': [2] ,'gamma':[0.01,0.02]}
#       5               ]
#       7 grid_search = GridSearchCV(estimator = svc,
#       8                            param_grid = parameters,
#       9                            scoring = 'f1_weighted',
#      10                            cv = 5,
#      11                            verbose=10)
# ---> 12 grid_search.fit(X_train.drop(columns=['retransmission', 'bandwidth']), t_train)
#      13 # examine the best model
#      14
#      15 # best score achieved during the GridSearchCV
#      16 print('GridSearch CV best score : {:.4f}\n\n'.format(grid_search.best_score_))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'
